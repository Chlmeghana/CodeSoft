# %%
#Step 1: Displaying of Sales Dataset
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,mean_squared_error
d=pd.read_csv('sales_task4.csv')
d
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
#Step 2: Data Analysis
sns.countplot(x="Sales",data=d)
# Out:
# <Axes: xlabel='Sales', ylabel='count'>

# %%
sns.countplot(x="TV",data=d,palette="summer")
# Out:
# <Axes: xlabel='TV', ylabel='count'>

# %%
sns.countplot(x="Radio",data=d,palette="summer")
# Out:
# <Axes: xlabel='Radio', ylabel='count'>

# %%
sns.countplot(x="Newspaper",data=d,palette="summer")
# Out:
# <Axes: xlabel='Newspaper', ylabel='count'>

# %%
#Step 3: Data Wrangling
d.isnull().sum()# Checking whether null values are present in the dataset
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
d=pd.read_csv('sales_task4.csv')

# %%
d
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
#Step 4: Train The Data
x=d.drop('Sales',axis=1)
y=d["Sales"]
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25) # Storing the trained and Tested Datasets

# %%
print(x_train,x_test,y_train,y_test)
# Out:
#         TV  Radio  Newspaper
# 165  234.5    3.4       84.8
# 109  255.4   26.9        5.5
# 187  191.1   28.7       18.2
# 189   18.7   12.1       23.4
# 119   19.4   16.0       22.3
# ..     ...    ...        ...
# 154  187.8   21.1        9.5
# 76    27.5    1.6       20.7
# 62   239.3   15.5       27.3
# 120  141.3   26.8       46.2
# 151  121.0    8.4       48.7
#
# [150 rows x 3 columns]         TV  Radio  Newspaper
# 161   85.7   35.8       49.3
# 129   59.6   12.0       43.1
# 191   75.5   10.8        6.0
# 73   129.4    5.7       31.3
# 48   227.2   15.8       49.9
# 105  137.9   46.4       59.0
# 3    151.5   41.3       58.5
# 64   131.1   42.8       28.9
# 156   93.9   43.5       50.5
# 56     7.3   28.1       41.4
# 142  220.5   33.2       37.9
# 199  232.1    8.6        8.7
# 114   78.2   46.8       34.5
# 158   11.7   36.9       45.2
# 144   96.2   14.8       38.9
# 83    68.4   44.5       35.6
# 85   193.2   18.4       65.7
# 168  215.4   23.6       57.6
# ...

# %%
print(d)
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
#Step 5:Perform Linear Regression
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction=lr.predict(x_test)
rmse=np.sqrt(mean_squared_error(y_test,prediction))
rmse#Since the output is 1.7, the prediction is 99% accurate
# Out:
# 1.712984007457005

# %%
new_data=pd.DataFrame({'TV':[230.1],'Radio':[89],'Newspaper':[76]})
prediction_new_data=lr.predict(new_data)
prediction_new_data #Sales Prediction with some example values
# Out:
# array([26.55234366])

# %%
new_data=pd.DataFrame({'TV':[170],'Radio':[819],'Newspaper':[716]})
prediction_new_data=lr.predict(new_data)
prediction_new_data #Sales Prediction with some example values
# Out:
# array([100.28704491])

# %%
prediction=lr.predict(x_test)
rmse=np.sqrt(mean_squared_error(y_test,prediction))
rmse
# Out:
# 1.712984007457005
